# %%
print("HELLO, INDIA!")
# Out:
# HELLO, INDIA!

# %%
x = 5
y = "Joe root"
print(x)
print(y)
# Out:
# 5
# Joe root

# %%
x = str(4)
y = int(5)
z = float(10)
print(x,y,z)
# Out:
# 4 5 10.0

# %%
x = 5
y = "10.8907"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "John"
x = 'siddharth'
print(x)
# Out:
# siddharth

# %%
a = 4
A = "saltest water"

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
x, y, z = "pine apple", "Blueberry", "apple"
print(x)
print(y)
print(z)
# Out:
# pine apple
# Blueberry
# apple

# %%
x = y = z = "papaya"
print(x)
print(y)
print(z)
# Out:
# papaya
# papaya
# papaya

# %%
fruits = ["orange", "banana", "guvava"]
x, y, z = fruits
print(x)
print(y)
print(fruits)
# Out:
# orange
# banana
# ['orange', 'banana', 'guvava']

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
thistuple = ("apple", "banana", "cherry", "apple", "cherry", 3, 5, 6, 'grapes')
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')
# ('apple', 'banana', 'cherry', 'apple', 'cherry', 3, 5, 6, 'grapes')

# %%
thisset = {"banana", "apple", "cherry", False, 1, 2}

print(thisset)
# Out:
# {False, 1, 2, 'cherry', 'apple', 'banana'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
x = "Python "
y = "is "
z = "easy"
print(x + y + z)
# Out:
# Python is easy

# %%
x = 5
y = "kiran hemanth"
print(x, y)
# Out:
# 5 kiran hemanth

# %%
import sys

print(sys.version)
# Out:
# 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]

# %%
if 3 > 2:
  print("three is greater than two!")
# Out:
# three is greater than two!

# %%
if 9 > 2:
 print("nine is greater than two!")
 if 10 > 1:
        print("ten is greater than two!")
# Out:
# nine is greater than two!
# ten is greater than two!

# %%
a = 33
b = 33
if b==a:
  print("b is equal to a")
elif a > b:
  print("a is greater than b")
# Out:
# b is equal to a

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
 colours = ["white", "blue", "camarron green"]
for x in colours:
  print(x)
# Out:
# white
# blue
# camarron green

# %%
for x in range(7):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Finally finished!

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "fantastic"

def myfunc():
  x = "fantastic"
  print("Python is not " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is not fantastic
# Python is fantastic
