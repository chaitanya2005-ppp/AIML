# %%
import pandas as pd

# %%
animal_dataset=pd.read_csv("animal_dataset.csv")

# %%
animal_dataset.head()
# Out:
#   Animals Size of Animal Body Color Can we Pet them
# 0     Dog         Medium      Black             Yes
# 1     Dog            Big      White              No
# 2     Rat          Small      White             Yes
# 3     Cow            Big      White             Yes
# 4     Cow          Small      Brown              No

# %%
animal_dataset.shape
# Out:
# (14, 4)

# %%
animal_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Animals          14 non-null     object
#  1   Size of Animal   14 non-null     object
#  2   Body Color       14 non-null     object
#  3   Can we Pet them  14 non-null     object
# dtypes: object(4)
# memory usage: 580.0+ bytes

# %%
animal_dataset.describe()
# Out:
#        Animals Size of Animal Body Color Can we Pet them
# count       14             14         14              14
# unique       3              3          3               2
# top        Dog            Big      White             Yes
# freq         5              5          5               8

# %%
animal_dataset.shape[0]
# Out:
# 14

# %%
animal_dataset.shape[1]
# Out:
# 4
